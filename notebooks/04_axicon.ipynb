# %% [markdown]
# # 04 — Axicon / Bessel beams
#
# Conical pupil phase A(θ)=exp(+jβ sinθ/sinα) → focal segment with position-dependent Bessel scale, u(θ*)=β sinα cotθ*. Durnin checkpoint: transverse @ predicted u = J₀²(v sinθ*/sinα) to 4–8%. **Flag:** that deviation is stationary-phase error (low≈high NA), not vector — the annulus is the clean vector-Bessel probe. See `docs/theory/04_axicon.md` and `docs/theory/FLAGS.md`.

# %% [markdown]
# Figure from `scripts/verify_axicon.py`.

# %%
import os
from IPython.display import Image, display
OUT = os.path.join('..', 'output')

# %% [markdown]
# ### Focal segment + Durnin checks
# (a) axial segment vs β; (b) low-NA Durnin (axicon vs J₀²); (c) axicon ≡ annulus ≡ J₀² at θ*=0.70α.

# %%
display(Image(os.path.join(OUT, '04_axicon/verify_axicon.png')))
