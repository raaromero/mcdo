# %% [markdown]
# # 05 — Pulsed × annular (new science)
#
# Eq.-10 spectral sum over annular fields. **Headline: the annular DOF extension is immune to few-cycle bandwidth** (44.35→44.33 cw→1 fs at ε=0.99); the transverse ring contrast erodes (Linfoot S→1.058 at 1 fs). ε=0 gives S(1fs)=1.056 = Phase-1 cross-check. **Flag:** S(τ) is non-monotonic at high ε (ring-washing). See `docs/theory/05_pulsed_pupils.md` and `FLAGS.md`.

# %% [markdown]
# Figures from `scripts/verify_pulsed_annular.py`, `verify_pulsed_ring_decomp.py`.

# %%
import os
from IPython.display import Image, display
OUT = os.path.join('..', 'output')

# %% [markdown]
# ### Pulsed × annular grid
# (a) ε=0.99 rings fill as τ↓; (b) full disk ref; (c) axial focus persists at 1 fs; (d) DOF(ε)/DOF(0) pulse-invariant.

# %%
display(Image(os.path.join(OUT, '05_pulsed_pupils/verify_pulsed_annular.png')))

# %% [markdown]
# ### Flag 2 confirmed — ring-washing
# S_ring dips below 1 (rings smooth) while S_central rises above 1 (broadening); the ring weight makes total S non-monotonic.

# %%
display(Image(os.path.join(OUT, '05_pulsed_pupils/ring_decomposition.png')))
