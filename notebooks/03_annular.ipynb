# %% [markdown]
# # 03 — Annular apertures (field-level Babinet)
#
# Annulus ε=r_in/r_out as the field-level difference of two disks at the same (r,z,k). DOF extension 1/(1−ε²) (3 digits at low NA, ~40% short at sinα=0.9); thin annulus → Durnin J₀² (and a genuine high-NA vector deformation, dev 0.163 vs 0.004). Strehl cost (1−ε²)². Validated against Sheppard & Wilson 1978. Full text: `docs/theory/03_annular_babinet.md`.

# %% [markdown]
# Figures from `scripts/verify_annular.py`, `verify_annular_energy.py`, `verify_sheppard.py`.

# %%
import os
from IPython.display import Image, display
OUT = os.path.join('..', 'output')

# %% [markdown]
# ### Profiles, DOF, illumination
# (a) transverse→J₀²; (b) axial extends; (c) DOF ratio vs theory low/high NA; (d) uniform≈Gaussian for thin annulus.

# %%
display(Image(os.path.join(OUT, '03_annular/verify_annular.png')))

# %% [markdown]
# ### The cost side
# Strehl tracks (1−ε²)² at both NAs; central-lobe energy collapses 0.76→0.055 as ε→1.

# %%
display(Image(os.path.join(OUT, '03_annular/annular_energy_cost.png')))

# %% [markdown]
# ### Literature anchor — Sheppard & Wilson 1978
# Fit a=0.200 from the focal envelope; the **predicted** axial profile (Eq. 33, not fitted) matches to 0.8%.

# %%
display(Image(os.path.join(OUT, '03_annular/verify_sheppard.png')))
